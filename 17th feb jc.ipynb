# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
v = 5
v
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[5], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
5v = 6
5v
# Out:
#   Cell In[6], line 1
#     5v = 6
#     ^
# SyntaxError: invalid decimal literal

# %%
v5 = 6
v5
# Out:
# 6

# %%
nit = 20
nit
# Out:
# 20

# %%
nit$ = 56
# Out:
#   Cell In[9], line 1
#     nit$ = 56
#        ^
# SyntaxError: invalid syntax

# %%
nit* = 9
# Out:
#   Cell In[10], line 1
#     nit* = 9
#          ^
# SyntaxError: invalid syntax

# %%
x_train = 80
x_train
# Out:
# 80

# %%
NiT = 7
NiT
# Out:
# 7

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for = 67
# Out:
#   Cell In[15], line 1
#     for = 67
#         ^
# SyntaxError: invalid syntax

# %%
For = 67

# %%
For
# Out:
# 67

# %%
False = 67
False
# Out:
#   Cell In[18], line 1
#     False = 67
#     ^
# SyntaxError: cannot assign to False

# %%
false = 67
false
# Out:
# 67

# %% [markdown]
# # Integer Datatype

# %%
i = 56
i
# Out:
# 56

# %%
id(i)
# Out:
# 140725186833032

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # basic

# %%
3 + 2
# Out:
# 5

# %%
3 - 2
# Out:
# 1

# %%
3 * 2
# Out:
# 6

# %%
3 /2
# Out:
# 1.5

# %%
3 ** 2
# Out:
# 9

# %%
3 % 2
# Out:
# 1

# %%
3 // 2
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
5 // 2
# Out:
# 2

# %% [markdown]
# # variables in pytthon

# %%
first_name = 'Tanvi' 
last_name = 'Vijay'
country = 'India'
age = 20
skills = ['html','java','css','python']

# %% [markdown]
# # printing the vlues stored in variable

# %%
print('first name : ',first_name)
print('last name : ',last_name)
print('country :', country)
print('age : ',age)
print('skills : ',skills)
# Out:
# first name :  Tanvi
# last name :  Vijay
# country : India
# age :  20
# skills :  ['html', 'java', 'css', 'python']

# %% [markdown]
# # declaring multiple variables in one line

# %%
first_name,last_name,country,age,skills='Tanvi','Vijay','India',20,['html','css','js']

# %%
print('first name : ',first_name)
print('last name : ',last_name)
print('country :', country)
print('age : ',age)
print('skills : ',skills)
# Out:
# first name :  Tanvi
# last name :  Vijay
# country : India
# age :  20
# skills :  ['html', 'css', 'js']
